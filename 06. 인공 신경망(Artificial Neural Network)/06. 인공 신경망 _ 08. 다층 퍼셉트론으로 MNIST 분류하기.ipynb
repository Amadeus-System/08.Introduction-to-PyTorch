# %% [markdown]
# ## 08.다층 퍼셉트론으로 MNIST 분류하기
#
# **아직 작성 중인 챕터이다.**
#
# 앞서 소프트맥스 회귀로 MNIST 데이터를 분류하는 실습을 해봤다. 소프트맥스 회귀 또한 인공 신경망이라고 볼 수 있는데, 입력층과 출력층만 존재하므로 소프트맥스 함수를 활성화 함수로 사용한 '단층 퍼셉트론'이라고 할 수 있다. 이번 챕터에서는 은닉층을 추가로 넣어 다층 퍼셉트론을 구현하고, 딥러닝을 통해서 MNIST 데이터를 분류해보자.
