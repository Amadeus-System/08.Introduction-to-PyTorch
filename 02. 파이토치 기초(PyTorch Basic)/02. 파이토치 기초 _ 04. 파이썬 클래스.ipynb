# %% [markdown]
# ## 04.파이썬 클래스(class)
#
# 대부분의 파이토치의 구현체들을 보면 기본적으로 클래스(Class)라는 개념을 애용하고 있다. 이번 챕터에서는 점프투파이썬의 클래스 챕터를 인용하였다.
#
# 링크 : https://wikidocs.net/28

# %% [markdown]
# ### 1.함수(Function)와 클래스(Class)의 차이
#
# 우선 함수와 클래스의 차이를 이해하기 위해서 덧셈을 지속적으로 수행할 수 있는 도구를 함수와 클래스로 각각 만들어보겠다.

# %% [markdown]
# #### 1.함수(function)로 덧셈기 구현하기
#
# 우선 add 함수를 파이썬으로 구현해보겠다.
#
# result라는 전역 변수를 선언한다.

# %%
result = 0

# %% [markdown]
# 그리고 add라는 함수를 구현한다. add라는 함수에서는 기존의 result에 함수의 인자로 온 숫자를 더하고 리턴한다.

# %%
def add(num):
    global result
    result += num
    return result

# %% [markdown]
# 함수를 두 번 실행시키는데 처음에는 3을 넣고, 두번째에는 4를 넣는다.

# %%
print(add(3))
print(add(4))
# Out:
# 3
# 7

# %% [markdown]
# 처음에는 result가 0이었다가 3이 더해지면서 3이 출력되고, 추가로 4를 입력하면 result의 값이 이미 앞서 3으로 갱신되었기 때문에 3 + 4의 결과로 7이 리턴된다.

# %% [markdown]
# #### 2.함수(function)로 두 개의 덧셈기 구현하기
#
# 이번에는 독립적인 두 개의 덧셈기를 만들어보고 싶다. 비유하면, 책상에 두 개의 계산기를 두고 서로 다른 연산을 하고 싶다. 첫번째 계산기로는 3 + 7을 하고 싶고, 두번째 계산기로는 3 + 10을 하고 싶은 것이다. 이 두 계산기는 서로 다른 계산기이므로 독립적이어야 한다. 이를 함수로 구현하려면, 하나의 함수는 1개의 덧셈기만을 의미하므로 이 경우에는 두 개의 함수를 독립적으로 만들어야 한다.

# %%
result1 = 0
result2 = 0

def add1(num):
    global result1
    result1 += num
    return result1

def add2(num):
    global result2
    result2 += num
    return result2

print(add1(3))
print(add1(4))
print(add2(3))
print(add2(7))
# Out:
# 3
# 7
# 3
# 10

# %% [markdown]
# 서로의 값에 영향을 주지않고 서로 다른 연산을 하고 있음을 볼 수 있다. 그렇다면 이런 두 개의 덧셈기를 클래스로 만들면 어떻게 될까?

# %% [markdown]
# ### 2.클래스(class)로 덧셈기 구현하기
#
# 이번에는 클래스로 구현해보겠다.

# %%
class Calculator():

    def __init__(self): # 객체 생성 시 호출될 때 실행되는 초기화 함수. 이를 생성자라고 한다.
        self.result = 0

    def add(self, num): # 객체 생성 후 사용할 수 있는 함수.
        self.result += num
        return self.result

# %% [markdown]
# 클래스는 마치 붕어빵 틀과 같아서 클래스를 생성한 후에는 이걸로 객체라는 것을 만들 수 있다. cal1이라는 객체를 만들겠다. 이는 붕어빵 틀로 하나의 붕어빵을 만드는 것에 비유된다.

# %%
cal1 = Calculator()

# %% [markdown]
# 객체의 생성 방법은 객체의 이름을 정한 뒤에 '=클래스이름()'으로 객체를 생성한다. 클래스가 붕어빵 틀과 같다는 이유는 하나의 클래스를 만든 후에는 여러 개의 객체를 만드는 것이 가능하기 때문이다. 또 하나의 객체 cal2도 생성해보겠다.

# %%
cal2 = Calculator()

# %% [markdown]
# 두 개의 객체를 생성하였다. 이제 두 개의 객체에 대해서 동시에 독립적인 덧셈 연산을 해보겠다.

# %%
print(cal1.add(3))
print(cal1.add(4))
print(cal2.add(3))
print(cal2.add(7))
# Out:
# 3
# 7
# 3
# 10

# %% [markdown]
# 두 개의 객체는 독립적으로 연산되고 있음을 알 수 있다. 앞에서는 이렇게 독립적인 두 개의 덧셈기를 함수로 구현하려고 했다면 함수를 두 개 만들어야 했지만, 클래스라는 것을 하나 선언하고, 이 클래스를 통해 별도의 객체를 생성하자 코드가 훨씬 간결해졌다.
